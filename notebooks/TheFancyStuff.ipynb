# %%
import pandas as pd

# %%
# !ls ../output
# Out:
# selection_roulette_28_generation_config_1.csv
# selection_roulette_crossover_mutation_0.05_28_generation_config_1.csv
# selection_tournament_28_generation_config_1.csv
# selection_tournament_crossover_mutation_0.05_28_generation_config_1.csv

# %% [markdown]
# ## ROULETTE SELECTION CONFIG 1 FOR 28 GENERATIONS

# %%
df1 = pd.read_csv('../output/selection_roulette_28_generation_config_1.csv')
df1 = df1.rename(columns={'Active_Gene_Count': 'Best_Fitness_Score', 'Best_Fitness_Score': 'Active_Gene_Count'})
df1.head()
# Out:
#    Generation  Avg_Population_Fitness  Avg_Population_Capacity  \
# 0         1.0                 1271.30                   247.30
# 1         2.0                 1477.95                   261.25
# 2         3.0                 1995.40                   213.75
# 3         4.0                 2188.20                   203.65
# 4         5.0                 2258.00                   189.00
#
#    Best_Fitness_Score  Active_Gene_Count
# 0              2258.0                7.0
# 1              2258.0                7.0
# 2              2258.0                7.0
# 3              2258.0                7.0
# 4              2258.0                7.0

# %%
df1.plot.line(x='Generation', y=['Avg_Population_Fitness', 'Avg_Population_Capacity', 'Active_Gene_Count', 'Best_Fitness_Score'])
# Out:
# <Axes: xlabel='Generation'>

# %% [markdown]
# ## TOURNAMENT SELECTION CONFIG 1 FOR 28 GENERATIONS

# %%
df2 = pd.read_csv('../output/selection_tournament_28_generation_config_1.csv')
df2 = df2.rename(columns={'Active_Gene_Count': 'Best_Fitness_Score', 'Best_Fitness_Score': 'Active_Gene_Count'})
df2.head()
# Out:
#    Generation  Avg_Population_Fitness  Avg_Population_Capacity  \
# 0         1.0                 1195.90                    290.6
# 1         2.0                 1335.45                    253.4
# 2         3.0                 1431.70                    248.3
# 3         4.0                 1480.90                    229.0
# 4         5.0                 1539.85                    209.5
#
#    Best_Fitness_Score  Active_Gene_Count
# 0              2258.0                7.0
# 1              2258.0                7.0
# 2              2258.0                7.0
# 3              1756.0                6.0
# 4              1756.0                6.0

# %%
df2.plot.line(x='Generation', y=['Avg_Population_Fitness', 'Avg_Population_Capacity', 'Active_Gene_Count', 'Best_Fitness_Score'])
# Out:
# <Axes: xlabel='Generation'>

# %% [markdown]
# ### ROULETTE SELECTION CONFIG 1 FOR 28 GENERATIONS WITH CROSSOVER AND MUTATION RATE OF 0.05

# %%
df3 = pd.read_csv('../output/selection_roulette_crossover_mutation_0.05_28_generation_config_1.csv')
df3 = df3.rename(columns={'Active_Gene_Count': 'Best_Fitness_Score', 'Best_Fitness_Score': 'Active_Gene_Count'})
df3.head()
# Out:
#    Generation  Avg_Population_Fitness  Avg_Population_Capacity  \
# 0         1.0                 1285.35                   241.75
# 1         2.0                 2219.35                   277.75
# 2         3.0                 2950.90                   393.15
# 3         4.0                 3585.65                   497.80
# 4         5.0                 3938.35                   520.80
#
#    Best_Fitness_Score  Active_Gene_Count
# 0              2258.0                7.0
# 1              3263.0               12.0
# 2              3719.0               14.0
# 3              4558.0               17.0
# 4              4547.0               19.0

# %%
df3.plot.line(x='Generation', y=['Avg_Population_Fitness', 'Avg_Population_Capacity', 'Active_Gene_Count', 'Best_Fitness_Score'])
# Out:
# <Axes: xlabel='Generation'>

# %% [markdown]
# ## TOURNAMENT SELECTION CONFIG 1 FOR 28 GENERATIONS WITH CROSSOVER AND MUTATION RATE OF 0.05

# %%
df4 = pd.read_csv('../output/selection_tournament_crossover_mutation_0.05_28_generation_config_1.csv')
df4 = df4.rename(columns={'Active_Gene_Count': 'Best_Fitness_Score', 'Best_Fitness_Score': 'Active_Gene_Count'})
df4.head()
# Out:
#    Generation  Avg_Population_Fitness  Avg_Population_Capacity  \
# 0         1.0                 1059.70                   278.00
# 1         2.0                 1982.25                   444.45
# 2         3.0                 2547.40                   532.60
# 3         4.0                 3568.80                   679.25
# 4         5.0                 4316.85                   623.40
#
#    Best_Fitness_Score  Active_Gene_Count
# 0              1756.0                6.0
# 1              2292.0                9.0
# 2              2993.0               12.0
# 3              4721.0               15.0
# 4              4799.0               16.0

# %%
df4.plot.line(x='Generation', y=['Avg_Population_Fitness', 'Avg_Population_Capacity', 'Active_Gene_Count', 'Best_Fitness_Score'])
# Out:
# <Axes: xlabel='Generation'>

# %%
df1
# Out:
#     Generation  Avg_Population_Fitness  Avg_Population_Capacity  \
# 0          1.0                 1271.30                   247.30
# 1          2.0                 1477.95                   261.25
# 2          3.0                 1995.40                   213.75
# 3          4.0                 2188.20                   203.65
# 4          5.0                 2258.00                   189.00
# 5          6.0                 2258.00                   189.00
# 6          7.0                 2258.00                   189.00
# 7          8.0                 2258.00                   189.00
# 8          9.0                 2258.00                   189.00
# 9         10.0                 2258.00                   189.00
# 10        11.0                 2258.00                   189.00
# 11        12.0                 2258.00                   189.00
# 12        13.0                 2258.00                   189.00
# 13        14.0                 2258.00                   189.00
# ...

# %%
df2
# Out:
#     Generation  Avg_Population_Fitness  Avg_Population_Capacity  \
# 0          1.0                 1195.90                    290.6
# 1          2.0                 1335.45                    253.4
# 2          3.0                 1431.70                    248.3
# 3          4.0                 1480.90                    229.0
# 4          5.0                 1539.85                    209.5
# 5          6.0                 1638.10                    177.0
# 6          7.0                 1657.75                    170.5
# 7          8.0                 1736.35                    144.5
# 8          9.0                 1756.00                    138.0
# 9         10.0                 1756.00                    138.0
# 10        11.0                 1756.00                    138.0
# 11        12.0                 1756.00                    138.0
# 12        13.0                 1756.00                    138.0
# 13        14.0                 1756.00                    138.0
# ...
